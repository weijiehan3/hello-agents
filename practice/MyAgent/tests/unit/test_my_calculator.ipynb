# %%
import sys
sys.path.insert(0, "../..") 

from dotenv import load_dotenv
from tools.builtin import my_calculator_tool

load_dotenv()
# Out:
# True

# %%
def test_calculator_tool():
    """测试自定义计算器工具"""

    # 创建包含计算器的注册表
    registry = my_calculator_tool.create_calculator_registry()

    # 简单测试用例
    test_cases = [
        ("2 + 3", 5),
        ("10 - 4", 6),
        ("5 * 6", 30),
        ("8 / 2", 4.0),
        ("2 ** 3", 8),
    ]

    for i, expression in enumerate(test_cases, 1):
        print(f"测试{i}: {expression[0]} = {expression[1]}")
